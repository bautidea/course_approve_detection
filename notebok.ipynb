# %% [markdown]
# ### Imports

# %%
# Analysis and wrangling.
import pandas as pd
import numpy as np
from unidecode import unidecode
import re

# Graphics libraries.
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Loading data / brief analysis.

# %%
student_df = pd.read_csv('./data/challenge_MLE.csv', sep=';')

# Transforming epoch to datetime
student_df['fecha_mesa_epoch'] = pd.to_datetime(student_df['fecha_mesa_epoch'], unit='s')
student_df['ass_created_at'] = pd.to_datetime(student_df['ass_created_at'], unit='s')
student_df['ass_due_at'] = pd.to_datetime(student_df['ass_due_at'], unit='s')
student_df['ass_unlock_at'] = pd.to_datetime(student_df['ass_unlock_at'], unit='s')
student_df['ass_lock_at'] = pd.to_datetime(student_df['ass_lock_at'], unit='s')
student_df['s_submitted_at'] = pd.to_datetime(student_df['s_submitted_at'], unit='s')
student_df['s_graded_at'] = pd.to_datetime(student_df['s_graded_at'], unit='s')
student_df['s_created_at'] = pd.to_datetime(student_df['s_created_at'], unit='s')

# Droping duplicates.
student_df.drop_duplicates(inplace=True)

student_df.sample(3)
# Out:
#         particion periodo  nota_final_materia fecha_mesa_epoch nombre_examen  \
# 127952         40  1-2022                 5.0              NaT           NaN
# 53108          17  1-2022                10.0              NaT           NaN
# 51314          59  1-2022                 7.0              NaT           NaN
#
#         nota_parcial  assignment_id ass_name ass_created_at ass_due_at  \
# 127952           NaN            NaN      NaN            NaT        NaT
# 53108            NaN            NaN      NaN            NaT        NaT
# 51314            NaN            NaN      NaN            NaT        NaT
#
#        ass_unlock_at ass_lock_at  points_possible ass_name_sub sub_uuid  \
# 127952           NaT         NaT              NaN          NaN      NaN
# 53108            NaT         NaT              NaN          NaN      NaN
# 51314            NaT         NaT              NaN          NaN      NaN
#
#         score submission_type s_submitted_at s_graded_at s_created_at  \
# 127952    NaN             NaN            NaT         NaT          NaT
# 53108     NaN             NaN            NaT         NaT          NaT
# 51314     NaN             NaN            NaT         NaT          NaT
#
#                                    user_uuid  \
# 127952  808f24e0-40f5-4095-93b3-8de0d8e426ed
# 53108   4b2dbad6-2dd4-483c-abe2-d66764a64b8f
# 51314   e39270be-a9b7-412c-9b2d-23f775ae8f77
#
#                                  course_uuid  \
# 127952  e873a748-c047-4460-9427-f0e33007ee4c
# 53108   12bb6bfa-8b01-46a8-8cc2-e0e84785fa1e
# 51314   076bbf49-961d-4bd7-92e9-3fd0796be1f7
#
#                               course_name     legajo
# 127952  Vision-oriented tertiary intranet  975781MEH
# 53108       Face-to-face regional concept  137924SSZ
# 51314    Enhanced coherent conglomeration  665827PQU

# %%
# Getting to know df.
student_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 194394 entries, 0 to 196123
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   particion           194394 non-null  int64
#  1   periodo             194394 non-null  object
#  2   nota_final_materia  194394 non-null  float64
#  3   fecha_mesa_epoch    7010 non-null    datetime64[ns]
#  4   nombre_examen       7010 non-null    object
#  5   nota_parcial        7010 non-null    float64
#  6   assignment_id       25807 non-null   float64
#  7   ass_name            25807 non-null   object
#  8   ass_created_at      25807 non-null   datetime64[ns]
#  9   ass_due_at          25807 non-null   datetime64[ns]
#  10  ass_unlock_at       24529 non-null   datetime64[ns]
#  11  ass_lock_at         25726 non-null   datetime64[ns]
#  12  points_possible     25807 non-null   float64
#  13  ass_name_sub        23993 non-null   object
#  14  sub_uuid            23993 non-null   object
#  15  score               23664 non-null   float64
#  16  submission_type     23993 non-null   object
#  17  s_submitted_at      23993 non-null   datetime64[ns]
#  18  s_graded_at         23665 non-null   datetime64[ns]
#  19  s_created_at        23993 non-null   datetime64[ns]
#  20  user_uuid           194394 non-null  object
#  21  course_uuid         194394 non-null  object
#  22  course_name         194394 non-null  object
#  23  legajo              194394 non-null  object
# dtypes: datetime64[ns](8), float64(5), int64(1), object(10)
# memory usage: 37.1+ MB

# %%
# Checking nulls.
pd.DataFrame([student_df.isnull().sum(), (student_df.isnull().sum() / student_df.shape[0] * 100).round(2)]).T
# Out:
#                            0      1
# particion                0.0   0.00
# periodo                  0.0   0.00
# nota_final_materia       0.0   0.00
# fecha_mesa_epoch    187384.0  96.39
# nombre_examen       187384.0  96.39
# nota_parcial        187384.0  96.39
# assignment_id       168587.0  86.72
# ass_name            168587.0  86.72
# ass_created_at      168587.0  86.72
# ass_due_at          168587.0  86.72
# ass_unlock_at       169865.0  87.38
# ass_lock_at         168668.0  86.77
# points_possible     168587.0  86.72
# ass_name_sub        170401.0  87.66
# sub_uuid            170401.0  87.66
# score               170730.0  87.83
# submission_type     170401.0  87.66
# s_submitted_at      170401.0  87.66
# s_graded_at         170729.0  87.83
# s_created_at        170401.0  87.66
# user_uuid                0.0   0.00
# course_uuid              0.0   0.00
# course_name              0.0   0.00
# legajo                   0.0   0.00

# %% [markdown]
# # Analyzing data.

# %%
# Checking the time partition.
student_df['particion'].hist()
# Out:
# <Axes: >

# %%
# Arranging time column.
student_df['periodo'] = student_df['periodo'].str.replace('01', '1')

# Checking the time partition.
student_df['periodo'].value_counts()
# Out:
# periodo
# 1-2022    193854
# 2-2022       540
# Name: count, dtype: int64

# %%
student_df['nota_final_materia'].hist()
# Out:
# <Axes: >

# %%
student_df['user_uuid'].value_counts()
# the min value for each user is 60, this means each user has a different time partition.
# there are 600 students.
# Out:
# user_uuid
# 518e8c5f-6632-450b-bcee-518807ff2e9f    1017
# ded91bdd-7998-4502-b2cb-9b0081eb3464     824
# f2dbd20e-13f8-4d5c-b4ee-70b5ed837d5a     757
# 6f171fde-7fb3-48e3-b5c0-e89c23631f1a     751
# e536d715-fb7a-4e0b-8ac8-bb48a4e39c49     744
#                                         ...
# 59db8682-a866-4f35-97d1-fbebd7675088      60
# 8b4d4ea7-664d-473c-8f6c-280744e645d4      60
# df99c926-9a5c-495a-803b-fe1c94743cbb      60
# 35bf6215-6f70-43f2-afd8-e668e5735347      60
# ed4e3e5e-5c10-4187-91f7-82114442b119      60
# Name: count, Length: 600, dtype: int64

# %%
student_df['legajo'].value_counts()
# There are 601 students id, this number doesnt correspond by 1 from the amount of students i've obtained above.
# Out:
# legajo
# 624097JCN    1017
# 614851WSA     824
# 694137GRI     757
# 372740JAI     751
# 210665AGT     744
#              ...
# 517004GYP      60
# 715923CNS      60
# 763896XAM      60
# 890983ESM      60
# 263794IKM      60
# Name: count, Length: 601, dtype: int64

# %%
repeated_student = student_df.value_counts(['user_uuid','legajo']).reset_index()
repeated_student['user_uuid'].value_counts()[:5]
# Out:
# user_uuid
# 9d0a3bf7-7efc-405f-bd96-60d75f6033b4    2
# 518e8c5f-6632-450b-bcee-518807ff2e9f    1
# 213ae9fc-8a0e-4f6e-ac45-522587f41c33    1
# 598e46d0-4067-4017-85bd-d50240ff5dd7    1
# 3c42f7c2-26c0-4b2f-a461-8a87431fb249    1
# Name: count, dtype: int64

# %%
# Checking the user_uuid 
mask = student_df['user_uuid'] == '9d0a3bf7-7efc-405f-bd96-60d75f6033b4'
student_df.loc[mask, ['legajo', 'user_uuid']].drop_duplicates()
# Out:
#           legajo                             user_uuid
# 42752  078920YCB  9d0a3bf7-7efc-405f-bd96-60d75f6033b4
# 96876  772439OKZ  9d0a3bf7-7efc-405f-bd96-60d75f6033b4

# %%
student_df['course_uuid'].value_counts()
# the min value for each course is 60, this means each user has a different time partition.
# there are 582 courses id.
# Out:
# course_uuid
# 2b274b15-83bb-4629-941e-fdc573af4e0b    11439
# c78af3b4-4574-4a82-8c41-45195ce43384    10206
# 12bb6bfa-8b01-46a8-8cc2-e0e84785fa1e     4489
# 0034afe6-e996-4c26-b0b9-24dbb9535465     3864
# 68005d22-90dc-42f6-b90a-409714481cbc     3537
#                                         ...
# c7608367-bb39-4722-9270-c93058669c2b       60
# c68a3c33-51e2-4dd0-9536-2288eca94fe5       60
# 132ed50b-ec8b-4ad1-973d-f02eab433a34       60
# aef3ac91-4ee5-4f4e-a7cf-620094fa81dc       60
# dc53bcc5-440d-4bab-93c7-a749c9eddd85       60
# Name: count, Length: 582, dtype: int64

# %%
student_df['course_name'].value_counts()
# there are 561 courses names, this doesnt correspond to the amount of curses uuid i've obtained above.
# Out:
# course_name
# Intuitive non-volatile ability                11439
# Object-based leadingedge help-desk            10206
# Face-to-face regional concept                  4489
# Stand-alone upward-trending secured line       4129
# Total radical adapter                          3537
#                                               ...
# Monitored regional artificial intelligence       60
# Grass-roots national middleware                  60
# Multi-channeled homogeneous policy               60
# Operative fresh-thinking knowledge user          60
# Operative systematic help-desk                   60
# Name: count, Length: 561, dtype: int64

# %% [markdown]
# From this little analysis i got that the information in this data set is segregated in different levels. Each row is a unique interaction or activity.
#
# So the goal will be to analyze the different variables and try to generate other useful variables from them.
#
# One thing to do before is to check the difference between the amounts of course_uuid / course_name and user_uuid / legajo

# %%
repeated_course_name = student_df.value_counts(['course_uuid','course_name']).reset_index()
repeated_course_name['course_name'].value_counts()[0:20]
# Out:
# course_name
# Monitored fault-tolerant Graphical User Interface    5
# Profound eco-centric installation                    3
# Customer-focused multi-state open architecture       2
# Ergonomic needs-based support                        2
# Optional exuding alliance                            2
# Phased composite orchestration                       2
# Quality-focused leadingedge budgetary management     2
# Down-sized 24hour migration                          2
# Enhanced coherent conglomeration                     2
# Function-based systemic info-mediaries               2
# Proactive fresh-thinking project                     2
# Customer-focused optimizing attitude                 2
# Cloned radical algorithm                             2
# Quality-focused systemic software                    2
# Implemented methodical function                      2
# Stand-alone upward-trending secured line             2
# Optimized object-oriented challenge                  2
# Optional foreground complexity                       1
# Operative dynamic migration                          1
# Up-sized radical emulation                           1
# Name: count, dtype: int64

# %%
# Checking the course name with the biggest amount of uuid.
mask = student_df['course_name'] == 'Monitored fault-tolerant Graphical User Interface'
student_df.loc[mask, ['course_name', 'course_uuid']].drop_duplicates()
# Out:
#                                               course_name  \
# 6452    Monitored fault-tolerant Graphical User Interface
# 26311   Monitored fault-tolerant Graphical User Interface
# 95977   Monitored fault-tolerant Graphical User Interface
# 164967  Monitored fault-tolerant Graphical User Interface
# 183738  Monitored fault-tolerant Graphical User Interface
#
#                                  course_uuid
# 6452    e2bf69a2-b722-427e-9dab-b03fd2c42e58
# 26311   d0e5e02d-0b17-46f5-9693-2040a606b858
# 95977   52fb613c-3227-41da-b2ca-9533318477a0
# 164967  5d589b98-5da6-46bf-b43d-a6f174834c51
# 183738  2a2a2207-20fc-46a8-aaf2-2d5af284ad38

# %%
student_df['nombre_examen'].value_counts()
# Out:
# nombre_examen
# SEGUNDO PARCIAL(20)                  3213
# PRIMER PARCIAL(20)                   3067
# INTEGRADOR(30)                        356
# RECUPERATORIO PRIMER PARCIAL(20)      242
# RECUPERATORIO SEGUNDO PARCIAL(20)     132
# Name: count, dtype: int64

# %%
# Eliminating white spaces at the begging and end of the string.
student_df['ass_name'] = student_df['ass_name'].str.strip()
# Replacing double spaces with single.
student_df['ass_name'] = student_df['ass_name'].str.replace('  ', ' ')
# Bringing all text to lower case.
student_df['ass_name'] = student_df['ass_name'].str.lower()
# Removing ticks from strings.
def remove_ticks(txt):
    if pd.notnull(txt):
        return unidecode(txt)
    else:
        return txt
    
student_df['ass_name'] = student_df['ass_name'].apply(remove_ticks)

student_df['ass_name'].value_counts()
# Out:
# ass_name
# trabajo practico 2 [tp2]                                                         3256
# actividad practica integradora 4 [api4]                                          3236
# trabajo practico 1 [tp1]                                                         3171
# actividad practica integradora 1 [api1]                                          3001
# actividad practica integradora 3 [api3]                                          2948
# actividad practica integradora 2 [api2]                                          2942
# trabajo practico 3 [tp3]                                                         2656
# trabajo practico 4 [tp4]                                                         2577
# trabajo practico 3 - diagnostico [ed3]                                            580
# trabajo practico 4 - diagnostico [ed4]                                            580
# la alienacion segun marx                                                           81
# actividad practica integradora [api2]                                              76
# actividad practica integradora [api3]                                              76
# actividad practica integradora [api4]                                              75
# actividad practica integradora [api1]                                              74
# actividad 4 [tp4]                                                                  53
# actividad 3 [tp3]                                                                  51
# actividad 2 [tp2]                                                                  50
# actividad 1 [tp1]                                                                  49
# trabajo practico 1 (parte 3) [tp1]                                                 26
# entregable 1 [tp1]                                                                 25
# entregable 2 [tp2]                                                                 25
# entregable 3 [tp3]                                                                 25
# entregable 4 [tp4]                                                                 25
# trabajo practico 3 - avanzado [tp3]                                                22
# trabajo practico 4 - basico [tp4]                                                  22
# trabajo practico 4 - avanzado [tp4]                                                22
# trabajo practico 3 - basico [tp3]                                                  22
# foro: "evaluacion de pares"                                                        15
# actividad practica integradora 4 [api4] nuevo                                      14
# apliquemos lo aprendido!                                                           12
# modulo 1 - unidad 2 - principio de oportunidad. profesora sofia diaz pucheta.       9
# trabajo practico 4 [tp4] copiar                                                     3
# tercera nota. ampliacion de la planta turistica de la ciudad de cordoba             3
# nuevo actividad practica integradora 1 [api1]                                       1
# entregable grupal 1                                                                 1
# entregable grupal 2                                                                 1
# entregable grupal 3                                                                 1
# entregable grupal 4                                                                 1
# Name: count, dtype: int64

# %%
# Eliminating white spaces at the begging and end of the string.
student_df['ass_name_sub'] = student_df['ass_name_sub'].str.strip()
# Replacing double spaces with single.
student_df['ass_name_sub'] = student_df['ass_name_sub'].str.replace('  ', ' ')
# Bringing all text to lower case.
student_df['ass_name_sub'] = student_df['ass_name_sub'].str.lower()
    
student_df['ass_name_sub'] = student_df['ass_name_sub'].apply(remove_ticks)

student_df['ass_name_sub'].value_counts()[0:60]
# Out:
# ass_name_sub
# trabajo practico 2 [tp2]                                  2913
# trabajo practico 1 [tp1]                                  2818
# actividad practica integradora 1 [api1]                   2619
# actividad practica integradora 2 [api2]                   2569
# actividad practica integradora 3 [api3]                   2521
# actividad practica integradora 4 [api4]                   2318
# trabajo practico 3 [tp3]                                  2279
# trabajo practico 4 [tp4]                                  2063
# trabajo practico 3 - diagnostico [ed3]                     534
# trabajo practico 4 - diagnostico [ed4]                     484
# trabajo practico 3 - avanzado [tp3]                        363
# trabajo practico 4 - avanzado [tp4]                        348
# evaluacion diagnostica                                     268
# test de autorregulacion - etapa de planificacion [ta1]     171
# trabajo practico 3 - basico [tp3]                          160
# test de autorregulacion - etapa de ejecucion [ta2]         154
# test de autorregulacion - etapa de monitoreo [ta3]         148
# trabajo practico 4 - basico [tp4]                          120
# actividad practica - m1                                    102
# autoevaluacion de la actividad practica 1 - m1              86
# actividad practica integradora [api1]                       67
# actividad practica integradora [api2]                       62
# autoevaluacion de la actividad practica 1 - m2              61
# actividad practica integradora [api3]                       60
# actividad practica integradora [api4]                       50
# actividad practica - m2                                     50
# actividad 4 [tp4]                                           44
# actividad 2 [tp2]                                           44
# actividad 3 [tp3]                                           43
# actividad 1 [tp1]                                           37
# actividad practica - m3                                     37
# autoevaluacion de la actividad practica 1 - m3              36
# foro: "evaluacion de pares"                                 26
# trabajo practico 1 (parte 3) [tp1]                          25
# entregable 2 [tp2]                                          24
# actividad practica - m4                                     23
# entregable 1 [tp1]                                          23
# autoevaluacion de la actividad practica 1 -m4               22
# la alienacion segun marx                                    18
# trabajo practico 1 (parte 2)                                18
# entregable 3 [tp3]                                          16
# entregable 4 [tp4]                                          16
# entregar convenio                                           14
# modulo 1 - actividad practica 1                             10
# entregar planilla                                            8
# actividad practica 1                                         8
# autoevaluacion 1                                             8
# modulo 1 - actividad practica 2                              8
# actividad practica integradora 1 [ap1]                       7
# autoevaluacion 4                                             6
# autoevaluacion diagnostica                                   6
# autoevaluacion 2                                             6
# modulo 1 - actividad practica 3                              6
# autoevaluacion de la actividad practica 1                    5
# convenios de practica solidaria                              5
# actividad practica 2                                         5
# autoevaluacion de la actividad practica 2                    4
# modulo 2 - actividad practica 2                              4
# actividad practica 3                                         4
# modulo 2 - actividad practica 3                              3
# Name: count, dtype: int64

# %%
student_df['submission_type'].value_counts()
# Out:
# submission_type
# external_tool        10104
# online_quiz           9926
# online_upload         3153
# basic_lti_launch       738
# discussion_topic        50
# online_text_entry       20
# media_recording          2
# Name: count, dtype: int64

# %% [markdown]
# # Data Wrangling.

# %% [markdown]
# im going top start by creating a unique variable that im going to use as index, by using the features user_uuid/course_uuid.

# %%
student_df['index'] = student_df['user_uuid'] + '/' + student_df['course_uuid']

# %%
# Amount of unique formed indexes.
len(student_df['index'].unique())
# Out:
# 2969

# %%
# Creating a new DF in which im going to concatenate the created features.
data = student_df.groupby(['index', 'nota_final_materia', 'periodo']).size().reset_index()[['index', 'nota_final_materia', 'periodo']]

data.index = data['index'].values
data.drop(columns='index', inplace=True)

print(f'Shape = {data.shape[0]} rows / {data.shape[1]} cols')
data.sample(2)
# Out:
# Shape = 2969 rows / 2 cols
#                                                     nota_final_materia periodo
# 8f55885f-1653-45d5-a4ad-3942f150f33e/c89b9539-c...                 9.0  1-2022
# c9f15060-d3e4-419b-9a16-dadeee19a145/6ff9e773-7...                 9.0  1-2022

# %% [markdown]
# ## Assignments.
# ### Appending information about assignments.

# %% [markdown]
# Im going to append to the created DF the information about differents assignments students have to do during the course.
#
# I've seen that a lot of assignments in the column 'ass_name' share the abbreviated name and number of the homework, like:
# * [tp1]
# * [tp2]
# * [api1]
# * etc.
#
# Ill try to separate that logic and create a column indicating the homework each student did.

# %%
# First ill need to bring all different assignments to same type.
# Im going to use regex.
pattern =r"\[(\w+)\]"
pattern_re = re.compile(pattern)

# This function will be applied with .apply(lambda) it will return the 1st 
# element that match the given pattern.
def extract_assessment_type (text):
    if pd.isnull(text):
        return np.nan
    
    pattern_search = pattern_re.search(text)
    # return pattern_search.group(1) if pattern_search else text
    return pattern_search.group(1) if pattern_search else text

# %%
# Im going to separate between assignments that were assigned and were submitted.
student_df['assigned_ass'] = student_df['ass_name'].copy()
student_df['submitted_ass'] = student_df['ass_name_sub'].copy()

# Obtaining assignments types.
student_df['assigned_ass'] = student_df['ass_name'].apply(lambda x: extract_assessment_type(x))
student_df['submitted_ass'] = student_df['ass_name_sub'].apply(lambda x: extract_assessment_type(x))

# %%
student_df['assigned_ass'].value_counts()
# Out:
# assigned_ass
# tp2                                                                              3331
# api4                                                                             3325
# tp1                                                                              3271
# api1                                                                             3076
# api3                                                                             3024
# api2                                                                             3018
# tp3                                                                              2776
# tp4                                                                              2702
# ed4                                                                               580
# ed3                                                                               580
# la alienacion segun marx                                                           81
# foro: "evaluacion de pares"                                                        15
# apliquemos lo aprendido!                                                           12
# modulo 1 - unidad 2 - principio de oportunidad. profesora sofia diaz pucheta.       9
# tercera nota. ampliacion de la planta turistica de la ciudad de cordoba             3
# entregable grupal 1                                                                 1
# entregable grupal 2                                                                 1
# entregable grupal 3                                                                 1
# entregable grupal 4                                                                 1
# Name: count, dtype: int64

# %%
student_df['submitted_ass'].value_counts()
# Out:
# submitted_ass
# tp2                      2981
# tp1                      2903
# tp3                      2861
# api1                     2686
# api2                     2631
#                          ...
# examen de suficiencia       1
# entregable grupal 1         1
# entregable grupal 2         1
# entregable grupal 3         1
# entregable grupal 4         1
# Name: count, Length: 62, dtype: int64

# %% [markdown]
# Based on the leftovers:
# * for the case of assigned assessments im going to keep those assessments that are important, like 'TPs', 'APIs' and 'EDs'.
# * As for submitted assignments im going to gather the remains into a single category 'otras_entregas'.
#
# Im doing this because the remaining assignments are not that many, and the name of them doesnt appear to imply importance.
#
# Th only assignment im going to drop from 'ass_name_sub' is 'evaluacion diagnostica' because that is usually an important assessment.

# %%
student_df['submitted_ass'] = student_df['submitted_ass'].replace('evaluacion diagnostica', np.nan)

# %%
assignments_names = ['api1', 'api2', 'api3', 'api4', 'ed3', 'ed4', 'tp1', 'tp2', 'tp3', 'tp4']

# First im going to ignore all assigned assessments that are not in the list.
mask_assigned_tps = ~student_df['assigned_ass'].isin(assignments_names) & student_df['assigned_ass'].notnull()
student_df.loc[mask_assigned_tps, 'assigned_ass'] = np.nan

# Now im going to replace assignments that has no relevant importance and assigned to a single category.
mask_submitted_tps = ~student_df['submitted_ass'].isin(assignments_names) & student_df['submitted_ass'].notnull()
student_df.loc[mask_submitted_tps, 'submitted_ass'] = 'otros_trabajos'

# %% [markdown]
# ### Obtaining assignments for each student

# %%
assigned_ass_df = student_df.groupby(['index', 'assigned_ass']).size().reset_index()
# Here im assigning a value of 1, in order to check what assignment each student receive.
assigned_ass_df.drop(columns=0, inplace=True)
assigned_ass_df['assigned'] = 1

# Creating a pivot table in order to transform the different assignments into columns.
assigned_ass_df = assigned_ass_df.pivot(index='index', columns='assigned_ass', values='assigned').reset_index().rename_axis(None, axis=1)

# Droping index col, and assigning it as index.
assigned_ass_df.index = assigned_ass_df['index'].values
assigned_ass_df.drop(columns='index', inplace=True)

# Obtaining column names.
assessment_cols = assigned_ass_df.columns.to_list()

# Merging information.
data = data.merge(assigned_ass_df, left_index=True, right_index=True, how='left')

# Filling nans with 0, this means that the student has no information about that assessment.
# And transforming type into int for those columns.
for col in assessment_cols:
    data[col] = data[col].fillna(0)
    data[col] = data[col].astype(int)

# %% [markdown]
# Now im going to flag the assignments that dont belong to a course, for example if in a given course the assessment 'api' isnt required for a student to complete, then its going to be flagged as -1.

# %%
# Defining a function to flag assignments that dont belong to a course.
def flag_unrequited_assignments(df, new_col_name):
    # Unique assignments for each course.
    unique_assignments_per_course = student_df[student_df['assigned_ass'].notnull()].groupby('course_uuid')['assigned_ass'].unique()
    
    # Appending course name to input df.
    course_name_df = student_df[['index', 'course_uuid']].copy().drop_duplicates()
    
    result = df.merge(course_name_df, how='left', left_index=True, right_index=False, right_on='index')
    
    result.index = result['index'].values
    result.drop(columns='index', inplace=True)
    
    for assignment in assessment_cols: # --> ['api1', 'api2', 'api3', 'api4', 'ed3', 'ed4', 'tp1', 'tp2', 'tp3', 'tp4']
    # Iterating over possible assignments that a course can have.
    # This element is an series that each row is a unique course with possible assignments a course can have.
    # For example.
    # ---
    # 0034afe6-e996-4c26-b0b9-24dbb9535465    [api1, api2, api3, api4, ed4, ed3, tp1, tp2]
    # f08bfeb75-fb35-4ac4-8916-1f7eda676892                           [tp1, tp2, tp3, tp4]
    # ---
        for course_uuid, possible_assignment_list in unique_assignments_per_course.items():
            # Then if the assignment is not present in possible assignment of the series.
            if assignment not in possible_assignment_list:
                # Keeping considered course.
                mask = result['course_uuid'] == course_uuid
                # And flagging the corresponding assignment column as -1.
                result.loc[mask, assignment] = -1
    
    # Droping course column
    result.drop(columns='course_uuid', inplace=True)
    
    # Renaming columns.
    for assignment in assessment_cols:
        rename = {assignment : f'{assignment}_{new_col_name}'}
        result.rename(columns=rename, inplace=True)
    
    return result

# %%
data = flag_unrequited_assignments(data,'asignado')
data.sample(3)
# Out:
#                                                     nota_final_materia  \
# 518e8c5f-6632-450b-bcee-518807ff2e9f/e873a748-c...                 5.0
# bca159c5-0b68-44b9-a44d-857fb4949bfc/b4bbd251-a...                 7.0
# c5c97f18-2e2b-40fc-a203-c5f457f5af08/0034afe6-e...                 7.0
#
#                                                    periodo  api1_asignado  \
# 518e8c5f-6632-450b-bcee-518807ff2e9f/e873a748-c...  1-2022              1
# bca159c5-0b68-44b9-a44d-857fb4949bfc/b4bbd251-a...  1-2022              1
# c5c97f18-2e2b-40fc-a203-c5f457f5af08/0034afe6-e...  1-2022              1
#
#                                                     api2_asignado  \
# 518e8c5f-6632-450b-bcee-518807ff2e9f/e873a748-c...              1
# bca159c5-0b68-44b9-a44d-857fb4949bfc/b4bbd251-a...              1
# c5c97f18-2e2b-40fc-a203-c5f457f5af08/0034afe6-e...              1
#
#                                                     api3_asignado  \
# 518e8c5f-6632-450b-bcee-518807ff2e9f/e873a748-c...              1
# bca159c5-0b68-44b9-a44d-857fb4949bfc/b4bbd251-a...              1
# c5c97f18-2e2b-40fc-a203-c5f457f5af08/0034afe6-e...              1
#
#                                                     api4_asignado  \
# 518e8c5f-6632-450b-bcee-518807ff2e9f/e873a748-c...              1
# bca159c5-0b68-44b9-a44d-857fb4949bfc/b4bbd251-a...              1
# c5c97f18-2e2b-40fc-a203-c5f457f5af08/0034afe6-e...              1
#
#                                                     ed3_asignado  \
# 518e8c5f-6632-450b-bcee-518807ff2e9f/e873a748-c...            -1
# bca159c5-0b68-44b9-a44d-857fb4949bfc/b4bbd251-a...            -1
# c5c97f18-2e2b-40fc-a203-c5f457f5af08/0034afe6-e...             1
#
#                                                     ed4_asignado  \
# 518e8c5f-6632-450b-bcee-518807ff2e9f/e873a748-c...            -1
# bca159c5-0b68-44b9-a44d-857fb4949bfc/b4bbd251-a...            -1
# c5c97f18-2e2b-40fc-a203-c5f457f5af08/0034afe6-e...             1
#
#                                                     tp1_asignado  \
# 518e8c5f-6632-450b-bcee-518807ff2e9f/e873a748-c...             1
# bca159c5-0b68-44b9-a44d-857fb4949bfc/b4bbd251-a...             1
# c5c97f18-2e2b-40fc-a203-c5f457f5af08/0034afe6-e...             1
#
#                                                     tp2_asignado  \
# 518e8c5f-6632-450b-bcee-518807ff2e9f/e873a748-c...             1
# bca159c5-0b68-44b9-a44d-857fb4949bfc/b4bbd251-a...             1
# c5c97f18-2e2b-40fc-a203-c5f457f5af08/0034afe6-e...             1
#
#                                                     tp3_asignado  tp4_asignado
# 518e8c5f-6632-450b-bcee-518807ff2e9f/e873a748-c...             1             1
# bca159c5-0b68-44b9-a44d-857fb4949bfc/b4bbd251-a...             1             1
# c5c97f18-2e2b-40fc-a203-c5f457f5af08/0034afe6-e...            -1            -1

# %% [markdown]
# ### Obtaining submission information for each assignment.

# %%
submitted_ass_df = student_df.groupby(['index', 'submitted_ass']).size().reset_index()

# Creating a pivot table in order to transform the different assignments into columns.
submitted_ass_df = submitted_ass_df.pivot(index='index', columns='submitted_ass', values=0).reset_index().rename_axis(None, axis=1)

# Droping index col, and assigning it as index.
submitted_ass_df.index = submitted_ass_df['index'].values
submitted_ass_df.drop(columns='index', inplace=True)

# Merging information.
data = data.merge(submitted_ass_df, left_index=True, right_index=True, how='left')

# Filling nans with 0, this means that the student has no information about that assessment.
# And transforming type into int for those columns.
for col in assessment_cols:
    data[col] = data[col].fillna(0)
    data[col] = data[col].astype(int)

data['otros_trabajos'] = data['otros_trabajos'].fillna(0)
data['otros_trabajos'] = data['otros_trabajos'].astype(int)

# %% [markdown]
# Again im going to flag those submissions that dont correspond to a course.

# %%
data = flag_unrequited_assignments(data,'presentado')
data.rename(columns={'otros_trabajos': 'otros_trabajos_presentado'}, inplace=True)

data.sample(3)
# Out:
#                                                     nota_final_materia  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...                 8.0
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...                 9.0
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...                10.0
#
#                                                    periodo  api1_asignado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...  1-2022              1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...  1-2022              1
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...  1-2022              1
#
#                                                     api2_asignado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...              1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...              1
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...              1
#
#                                                     api3_asignado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...              1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...              1
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...              1
#
#                                                     api4_asignado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...              1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...              1
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...              1
#
#                                                     ed3_asignado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...            -1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...            -1
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...            -1
#
#                                                     ed4_asignado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...            -1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...            -1
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...            -1
#
#                                                     tp1_asignado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...             1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...             1
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...             1
#
#                                                     tp2_asignado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...             1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...             1
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...             1
#
#                                                     tp3_asignado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...             1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...             1
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...             1
#
#                                                     tp4_asignado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...             1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...             1
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...             1
#
#                                                     api1_presentado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...                1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...                1
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...                1
#
#                                                     api2_presentado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...                1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...                1
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...                1
#
#                                                     api3_presentado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...                1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...                2
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...                1
#
#                                                     api4_presentado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...                1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...                1
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...                0
#
#                                                     ed3_presentado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...              -1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...              -1
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...              -1
#
#                                                     ed4_presentado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...              -1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...              -1
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...              -1
#
#                                                     otros_trabajos_presentado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...                          0
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...                          0
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...                          0
#
#                                                     tp1_presentado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...               1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...               1
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...               1
#
#                                                     tp2_presentado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...               1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...               1
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...               1
#
#                                                     tp3_presentado  \
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...               0
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...               2
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...               1
#
#                                                     tp4_presentado
# 311a05f9-6e16-4746-bc27-c41e0cf8a3a0/06dd5f32-2...               1
# b1db9694-a53a-4a9b-b84f-b796be755851/94f740ed-1...               0
# 01193bc4-6b73-4fab-9a63-e425a2e397dd/3fab895d-e...               0

# %% [markdown]
# ### Obtaining scores for each assignment submission.

# %%
submitted_ass_score_df = student_df.groupby(['index', 'submitted_ass'])['score'].mean().reset_index()

# Creating a pivot table in order to transform the different assignments into columns.
submitted_ass_score_df = submitted_ass_score_df.pivot(index='index', columns='submitted_ass', values='score').reset_index().rename_axis(None, axis=1)

# Droping index col, and assigning it as index.
submitted_ass_score_df.index = submitted_ass_score_df['index'].values
submitted_ass_score_df.drop(columns='index', inplace=True)

# Merging information.
data = data.merge(submitted_ass_score_df, left_index=True, right_index=True, how='left')

# Filling nans with 0, this means that the student has no information about that assessment.
# And transforming type into int for those columns.
for col in assessment_cols:
    data[col] = data[col].fillna(0)
    data[col] = data[col].astype(float)
    data[col] = np.round(data[col],2)

data['otros_trabajos'] = data['otros_trabajos'].fillna(-1)
data['otros_trabajos'] = data['otros_trabajos'].astype(float)
data['otros_trabajos'] = np.round(data['otros_trabajos'],2)

# %%
data = flag_unrequited_assignments(data,'score')

data.rename(columns={'otros_trabajos': 'otros_trabajos_score'}, inplace=True)
# Out:
#                                                     nota_final_materia  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...                 2.0
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...                 8.0
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...                 7.0
#
#                                                    periodo  api1_asignado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...  1-2022              1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...  1-2022              1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...  1-2022              1
#
#                                                     api2_asignado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...              1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...              1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...              1
#
#                                                     api3_asignado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...              1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...              1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...              1
#
#                                                     api4_asignado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...              1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...              1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...              1
#
#                                                     ed3_asignado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...            -1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...            -1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...            -1
#
#                                                     ed4_asignado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...            -1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...            -1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...            -1
#
#                                                     tp1_asignado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...             1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...             1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...             1
#
#                                                     tp2_asignado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...             1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...             1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...             1
#
#                                                     tp3_asignado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...             1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...             1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...             1
#
#                                                     tp4_asignado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...             1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...             1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...             1
#
#                                                     api1_presentado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...                1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...                1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...                1
#
#                                                     api2_presentado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...                1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...                1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...                1
#
#                                                     api3_presentado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...                1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...                1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...                0
#
#                                                     api4_presentado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...                0
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...                1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...                1
#
#                                                     ed3_presentado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...              -1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...              -1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...              -1
#
#                                                     ed4_presentado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...              -1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...              -1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...              -1
#
#                                                     otros_trabajos_presentado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...                          0
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...                          0
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...                          1
#
#                                                     tp1_presentado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...               1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...               1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...               1
#
#                                                     tp2_presentado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...               1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...               1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...               1
#
#                                                     tp3_presentado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...               1
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...               0
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...               4
#
#                                                     tp4_presentado  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...               0
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...               1
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...               0
#
#                                                     api1_score  api2_score  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...       100.0       100.0
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...       100.0        11.8
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...        89.0       100.0
#
#                                                     api3_score  api4_score  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...        83.3         0.0
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...       100.0        68.4
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...         0.0        96.0
#
#                                                     ed3_score  ed4_score  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...       -1.0       -1.0
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...       -1.0       -1.0
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...       -1.0       -1.0
#
#                                                     otros_trabajos_score  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...                  -1.0
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...                  -1.0
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...                  -1.0
#
#                                                     tp1_score  tp2_score  \
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...       55.0      55.00
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...       80.0      78.33
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...       70.0      54.17
#
#                                                     tp3_score  tp4_score
# a3304677-16c0-4c8c-834a-4f24df0e8c0e/a2d8a260-0...       65.0        0.0
# aee67208-e3c2-49ca-92c6-8fa9333a85b4/03893f0c-7...        0.0       57.5
# 824f65c1-455d-4101-bc68-da7eecb21f1b/01ef15c9-2...       52.5        0.0

# %%
# Going to sort columns alphabetically
sorted_columns = data.columns.to_list()
# Removing columns so they dont get sorted.
sorted_columns.remove('nota_final_materia')
sorted_columns.remove('periodo')

sorted_columns.sort()

# Appending columns in 1st place
sorted_columns.insert(0,'nota_final_materia')
sorted_columns.insert(1,'periodo')

data = data[sorted_columns].copy()
data.sample(3)
# Out:
#                                                     nota_final_materia  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...                 7.0
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...                 6.0
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...                 8.0
#
#                                                    periodo  api1_asignado  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...  1-2022              1
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...  1-2022              1
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...  1-2022              1
#
#                                                     api1_presentado  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...                0
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...                1
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...                1
#
#                                                     api1_score  api2_asignado  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...         0.0              1
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...       100.0              1
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...        75.0              1
#
#                                                     api2_presentado  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...                0
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...                1
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...                1
#
#                                                     api2_score  api3_asignado  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...         0.0              1
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...       100.0              1
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...        90.0              1
#
#                                                     api3_presentado  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...                0
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...                1
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...                1
#
#                                                     api3_score  api4_asignado  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...         0.0              1
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...       100.0              1
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...       100.0              1
#
#                                                     api4_presentado  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...                0
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...                1
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...                1
#
#                                                     api4_score  ed3_asignado  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...         0.0            -1
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...       100.0            -1
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...        92.9            -1
#
#                                                     ed3_presentado  ed3_score  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...              -1       -1.0
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...              -1       -1.0
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...              -1       -1.0
#
#                                                     ed4_asignado  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...            -1
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...            -1
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...            -1
#
#                                                     ed4_presentado  ed4_score  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...              -1       -1.0
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...              -1       -1.0
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...              -1       -1.0
#
#                                                     otros_trabajos_presentado  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...                          0
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...                          0
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...                          0
#
#                                                     otros_trabajos_score  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...                  -1.0
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...                  -1.0
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...                  -1.0
#
#                                                     tp1_asignado  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...             1
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...             1
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...             1
#
#                                                     tp1_presentado  tp1_score  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...               0       0.00
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...               1      86.67
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...               1      65.00
#
#                                                     tp2_asignado  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...             1
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...             1
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...             1
#
#                                                     tp2_presentado  tp2_score  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...               0       0.00
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...               1      92.50
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...               1      59.17
#
#                                                     tp3_asignado  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...             1
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...             1
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...             1
#
#                                                     tp3_presentado  tp3_score  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...               0        0.0
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...               1       85.0
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...               1       80.0
#
#                                                     tp4_asignado  \
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...             1
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...             1
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...             1
#
#                                                     tp4_presentado  tp4_score
# 03edbe94-38c1-46bb-ac89-4f84b5cee7f0/06dd5f32-2...               1      100.0
# aa135ece-1d06-4c2e-9b8d-65c3919bb90b/41fc218f-a...               1       92.5
# 2754f3f3-5dcb-4e04-8163-3887566d15a3/5c748576-a...               1       67.5

# %% [markdown]
# # Draft

# %%
mask = student_df['course_name'] == 'Automated homogeneous ability'

student_df[mask & mask_ass_name]
# Out:
#         particion periodo  nota_final_materia fecha_mesa_epoch nombre_examen  \
# 168103         24  1-2022                 8.0              NaT           NaN
#
#         nota_parcial  assignment_id             ass_name      ass_created_at  \
# 168103           NaN       208185.0  entregable grupal 1 2022-04-12 16:12:19
#
#                 ass_due_at ass_unlock_at         ass_lock_at  points_possible  \
# 168103 2022-04-22 02:59:00           NaT 2022-04-22 02:59:59            100.0
#
#                ass_name_sub                              sub_uuid  score  \
# 168103  entregable grupal 1  4dd72c05-8dc8-4444-b9e5-123833cd822a   85.0
#
#        submission_type      s_submitted_at         s_graded_at  \
# 168103   online_upload 2022-04-22 02:30:42 2022-04-25 09:37:49
#
#               s_created_at                             user_uuid  \
# 168103 2022-08-01 22:27:07  265760ef-f154-4718-a934-4bbe71417bdb
#
#                                  course_uuid                    course_name  \
# 168103  54044046-b9ab-4436-ad96-ac952b02b7d9  Automated homogeneous ability
#
#            legajo                                              index  \
# 168103  787645DVM  265760ef-f154-4718-a934-4bbe71417bdb/54044046-...
#
#                    ass_type
# 168103  entregable grupal 1

# %%
student_df.loc[student_df['ass_name_sub'].notnull() & student_df['ass_name'].isnull(),'ass_name_sub'].value_counts()[0:60]
# Out:
# ass_name_sub
# actividad practica integradora 1 [api1]                   2223
# actividad practica integradora 2 [api2]                   2081
# actividad practica integradora 3 [api3]                   1927
# actividad practica integradora 4 [api4]                   1909
# trabajo practico 1 [tp1]                                  1847
# trabajo practico 2 [tp2]                                  1755
# trabajo practico 3 [tp3]                                  1459
# trabajo practico 4 [tp4]                                  1267
# trabajo practico 3 - diagnostico [ed3]                     264
# evaluacion diagnostica                                     247
# trabajo practico 4 - diagnostico [ed4]                     228
# test de autorregulacion - etapa de planificacion [ta1]     169
# test de autorregulacion - etapa de ejecucion [ta2]         150
# trabajo practico 3 - avanzado [tp3]                        148
# test de autorregulacion - etapa de monitoreo [ta3]         146
# trabajo practico 4 - avanzado [tp4]                        137
# trabajo practico 3 - basico [tp3]                           94
# actividad practica - m1                                     89
# autoevaluacion de la actividad practica 1 - m1              77
# trabajo practico 4 - basico [tp4]                           73
# autoevaluacion de la actividad practica 1 - m2              57
# actividad practica integradora [api1]                       52
# actividad practica - m2                                     45
# actividad practica integradora [api2]                       43
# actividad practica integradora [api3]                       42
# actividad practica integradora [api4]                       33
# actividad practica - m3                                     32
# autoevaluacion de la actividad practica 1 - m3              29
# foro: "evaluacion de pares"                                 24
# actividad 1 [tp1]                                           22
# actividad 4 [tp4]                                           20
# actividad practica - m4                                     18
# trabajo practico 1 (parte 2)                                18
# autoevaluacion de la actividad practica 1 -m4               17
# actividad 2 [tp2]                                           14
# entregar convenio                                           14
# trabajo practico 1 (parte 3) [tp1]                          13
# la alienacion segun marx                                    12
# actividad 3 [tp3]                                           11
# modulo 1 - actividad practica 1                              9
# entregable 1 [tp1]                                           8
# autoevaluacion 1                                             8
# modulo 1 - actividad practica 2                              8
# actividad practica integradora 1 [ap1]                       7
# entregable 2 [tp2]                                           7
# modulo 1 - actividad practica 3                              6
# actividad practica 1                                         6
# autoevaluacion 2                                             5
# autoevaluacion diagnostica                                   5
# entregar planilla                                            5
# autoevaluacion 4                                             5
# actividad practica 2                                         4
# convenios de practica solidaria                              4
# modulo 2 - actividad practica 2                              4
# modulo 3 - actividad practica 1                              3
# modulo 2 - actividad practica 3                              3
# modulo 2 - actividad practica 1                              3
# actividad practica 3                                         3
# autoevaluacion de la actividad practica 1                    3
# diagnostico                                                  2
# Name: count, dtype: int64

# %%
student_df.groupby(['index','particion']).size()[student_df.groupby(['index','particion']).size() > 1]
# Out:
# index                                                                      particion
# 01103370-3046-4bc0-a8f8-85858ec0ec88/2dd2ca01-a672-4eca-aca7-6fbc8cd01953  49           4
#                                                                            55           4
# 01103370-3046-4bc0-a8f8-85858ec0ec88/a8c25bca-c5e5-4225-b51e-f61468d20386  55           3
#                                                                            57           8
# 01103370-3046-4bc0-a8f8-85858ec0ec88/bf8d7a98-903d-4dea-b4d2-275394aa0a06  30           6
#                                                                                        ..
# ff6b6af0-b7d7-42f4-821d-afd5ee6ef9a5/68005d22-90dc-42f6-b90a-409714481cbc  56           4
# ff6b6af0-b7d7-42f4-821d-afd5ee6ef9a5/c78af3b4-4574-4a82-8c41-45195ce43384  27           4
#                                                                            45           3
#                                                                            57           4
# ff6b6af0-b7d7-42f4-821d-afd5ee6ef9a5/f3632565-3ab8-4b7f-9ced-097ce82eb1c5  22           3
# Length: 7213, dtype: int64

# %%
a = student_df['index'] == '01103370-3046-4bc0-a8f8-85858ec0ec88/a8c25bca-c5e5-4225-b51e-f61468d20386'
b = student_df['particion'] == 57
student_df.loc[a & b]
# Out:
#         particion periodo  nota_final_materia fecha_mesa_epoch nombre_examen  \
# 150737         57  1-2022                 9.0              NaT           NaN
# 150738         57  1-2022                 9.0              NaT           NaN
# 150739         57  1-2022                 9.0              NaT           NaN
# 150740         57  1-2022                 9.0              NaT           NaN
# 150741         57  1-2022                 9.0              NaT           NaN
# 150742         57  1-2022                 9.0              NaT           NaN
# 150743         57  1-2022                 9.0              NaT           NaN
# 150744         57  1-2022                 9.0              NaT           NaN
#
#         nota_parcial  assignment_id                                ass_name  \
# 150737           NaN       209013.0  trabajo practico 3 - diagnostico [ed3]
# 150738           NaN       208981.0                trabajo practico 1 [tp1]
# 150739           NaN       208964.0       trabajo practico 3 - basico [tp3]
# 150740           NaN       209019.0     trabajo practico 3 - avanzado [tp3]
# 150741           NaN       208937.0  trabajo practico 4 - diagnostico [ed4]
# 150742           NaN       209007.0                trabajo practico 2 [tp2]
# 150743           NaN       209000.0     trabajo practico 4 - avanzado [tp4]
# 150744           NaN       209030.0       trabajo practico 4 - basico [tp4]
#
#             ass_created_at          ass_due_at       ass_unlock_at  \
# 150737 2022-04-19 18:56:42 2022-07-19 02:59:59                 NaT
# 150738 2022-04-19 18:56:40 2022-07-19 02:59:59 2022-05-23 03:00:00
# 150739 2022-04-19 18:56:39 2022-07-19 02:59:59 2022-05-23 03:00:00
# 150740 2022-04-19 18:56:43 2022-07-19 02:59:59 2022-05-23 03:00:00
# 150741 2022-04-19 18:56:36 2022-07-19 02:59:59                 NaT
# 150742 2022-04-19 18:56:42 2022-07-19 02:59:59 2022-05-23 03:00:00
# 150743 2022-04-19 18:56:41 2022-07-19 02:59:59 2022-05-23 03:00:00
# 150744 2022-04-19 18:56:44 2022-07-19 02:59:59 2022-05-23 03:00:00
#
#                ass_lock_at  points_possible ass_name_sub sub_uuid  score  \
# 150737 2022-07-19 02:59:59            100.0          NaN      NaN    NaN
# 150738 2022-07-19 02:59:59            100.0          NaN      NaN    NaN
# 150739 2022-07-19 02:59:59            100.0          NaN      NaN    NaN
# 150740 2022-07-19 02:59:59            100.0          NaN      NaN    NaN
# 150741 2022-07-19 02:59:59            100.0          NaN      NaN    NaN
# 150742 2022-07-19 02:59:59            100.0          NaN      NaN    NaN
# 150743 2022-07-19 02:59:59            100.0          NaN      NaN    NaN
# 150744 2022-07-19 02:59:59            100.0          NaN      NaN    NaN
#
#        submission_type s_submitted_at s_graded_at s_created_at  \
# 150737             NaN            NaT         NaT          NaT
# 150738             NaN            NaT         NaT          NaT
# 150739             NaN            NaT         NaT          NaT
# 150740             NaN            NaT         NaT          NaT
# 150741             NaN            NaT         NaT          NaT
# 150742             NaN            NaT         NaT          NaT
# 150743             NaN            NaT         NaT          NaT
# 150744             NaN            NaT         NaT          NaT
#
#                                    user_uuid  \
# 150737  01103370-3046-4bc0-a8f8-85858ec0ec88
# 150738  01103370-3046-4bc0-a8f8-85858ec0ec88
# 150739  01103370-3046-4bc0-a8f8-85858ec0ec88
# 150740  01103370-3046-4bc0-a8f8-85858ec0ec88
# 150741  01103370-3046-4bc0-a8f8-85858ec0ec88
# 150742  01103370-3046-4bc0-a8f8-85858ec0ec88
# 150743  01103370-3046-4bc0-a8f8-85858ec0ec88
# 150744  01103370-3046-4bc0-a8f8-85858ec0ec88
#
#                                  course_uuid                     course_name  \
# 150737  a8c25bca-c5e5-4225-b51e-f61468d20386  Enhanced non-volatile analyzer
# 150738  a8c25bca-c5e5-4225-b51e-f61468d20386  Enhanced non-volatile analyzer
# 150739  a8c25bca-c5e5-4225-b51e-f61468d20386  Enhanced non-volatile analyzer
# 150740  a8c25bca-c5e5-4225-b51e-f61468d20386  Enhanced non-volatile analyzer
# 150741  a8c25bca-c5e5-4225-b51e-f61468d20386  Enhanced non-volatile analyzer
# 150742  a8c25bca-c5e5-4225-b51e-f61468d20386  Enhanced non-volatile analyzer
# 150743  a8c25bca-c5e5-4225-b51e-f61468d20386  Enhanced non-volatile analyzer
# 150744  a8c25bca-c5e5-4225-b51e-f61468d20386  Enhanced non-volatile analyzer
#
#            legajo                                              index
# 150737  532479OLL  01103370-3046-4bc0-a8f8-85858ec0ec88/a8c25bca-...
# 150738  532479OLL  01103370-3046-4bc0-a8f8-85858ec0ec88/a8c25bca-...
# 150739  532479OLL  01103370-3046-4bc0-a8f8-85858ec0ec88/a8c25bca-...
# 150740  532479OLL  01103370-3046-4bc0-a8f8-85858ec0ec88/a8c25bca-...
# 150741  532479OLL  01103370-3046-4bc0-a8f8-85858ec0ec88/a8c25bca-...
# 150742  532479OLL  01103370-3046-4bc0-a8f8-85858ec0ec88/a8c25bca-...
# 150743  532479OLL  01103370-3046-4bc0-a8f8-85858ec0ec88/a8c25bca-...
# 150744  532479OLL  01103370-3046-4bc0-a8f8-85858ec0ec88/a8c25bca-...

# %%
b = student_df['ass_name'] == 'la alienacion segun marx'
student_df.loc[b]
# Out:
#         particion periodo  nota_final_materia fecha_mesa_epoch nombre_examen  \
# 6250           56  1-2022                 4.0              NaT           NaN
# 17671          56  1-2022                 7.0              NaT           NaN
# 19936          56  1-2022                 9.0              NaT           NaN
# 22902          56  1-2022                 5.0              NaT           NaN
# 33586          56  1-2022                 7.0              NaT           NaN
# ...           ...     ...                 ...              ...           ...
# 175553         56  1-2022                 7.0              NaT           NaN
# 176529         56  1-2022                 6.0              NaT           NaN
# 193963         56  1-2022                 9.0              NaT           NaN
# 195033         56  1-2022                10.0              NaT           NaN
# 195850         56  1-2022                 7.0              NaT           NaN
#
#         nota_parcial  assignment_id                  ass_name  \
# 6250             NaN       215922.0  la alienacion segun marx
# 17671            NaN       215922.0  la alienacion segun marx
# 19936            NaN       215922.0  la alienacion segun marx
# 22902            NaN       215922.0  la alienacion segun marx
# 33586            NaN       215922.0  la alienacion segun marx
# ...              ...            ...                       ...
# 175553           NaN       215922.0  la alienacion segun marx
# 176529           NaN       215922.0  la alienacion segun marx
# 193963           NaN       215922.0  la alienacion segun marx
# 195033           NaN       215922.0  la alienacion segun marx
# 195850           NaN       215922.0  la alienacion segun marx
#
#             ass_created_at          ass_due_at ass_unlock_at ass_lock_at  \
# 6250   2022-06-22 22:29:59 2022-07-17 02:59:00           NaT         NaT
# 17671  2022-06-22 22:29:59 2022-07-17 02:59:00           NaT         NaT
# 19936  2022-06-22 22:29:59 2022-07-17 02:59:00           NaT         NaT
# 22902  2022-06-22 22:29:59 2022-07-17 02:59:00           NaT         NaT
# 33586  2022-06-22 22:29:59 2022-07-17 02:59:00           NaT         NaT
# ...                    ...                 ...           ...         ...
# 175553 2022-06-22 22:29:59 2022-07-17 02:59:00           NaT         NaT
# 176529 2022-06-22 22:29:59 2022-07-17 02:59:00           NaT         NaT
# 193963 2022-06-22 22:29:59 2022-07-17 02:59:00           NaT         NaT
# 195033 2022-06-22 22:29:59 2022-07-17 02:59:00           NaT         NaT
# 195850 2022-06-22 22:29:59 2022-07-17 02:59:00           NaT         NaT
#
#         points_possible                            ass_name_sub  \
# 6250                0.0                                     NaN
# 17671               0.0                                     NaN
# 19936               0.0                                     NaN
# 22902               0.0     trabajo practico 4 - avanzado [tp4]
# 33586               0.0                trabajo practico 2 [tp2]
# ...                 ...                                     ...
# 175553              0.0                                     NaN
# 176529              0.0                                     NaN
# 193963              0.0                                     NaN
# 195033              0.0  trabajo practico 3 - diagnostico [ed3]
# 195850              0.0                                     NaN
#
#                                     sub_uuid      score submission_type  \
# 6250                                     NaN        NaN             NaN
# 17671                                    NaN        NaN             NaN
# 19936                                    NaN        NaN             NaN
# 22902   975a77f1-03e4-4ab1-9182-dff300d8cb44  92.500000     online_quiz
# 33586   83375f78-8b2c-4e73-a55d-e89bfbf832f6  86.250000     online_quiz
# ...                                      ...        ...             ...
# 175553                                   NaN        NaN             NaN
# 176529                                   NaN        NaN             NaN
# 193963                                   NaN        NaN             NaN
# 195033  f5352858-b91d-4211-86a6-6aee10ed9c84  86.666667     online_quiz
# 195850                                   NaN        NaN             NaN
#
#             s_submitted_at         s_graded_at        s_created_at  \
# 6250                   NaT                 NaT                 NaT
# 17671                  NaT                 NaT                 NaT
# 19936                  NaT                 NaT                 NaT
# 22902  2022-07-16 18:30:11 2022-07-16 18:30:11 2022-08-01 22:27:07
# 33586  2022-07-18 04:40:18 2022-07-18 04:40:18 2022-08-01 22:27:07
# ...                    ...                 ...                 ...
# 175553                 NaT                 NaT                 NaT
# 176529                 NaT                 NaT                 NaT
# 193963                 NaT                 NaT                 NaT
# 195033 2022-07-18 02:40:28 2022-07-18 02:40:28 2022-08-01 22:27:07
# 195850                 NaT                 NaT                 NaT
#
#                                    user_uuid  \
# 6250    9f4a4427-4807-4b56-8f32-024a45037ba4
# 17671   b8d84394-f416-4b70-b831-782dcb8998ca
# 19936   9940480d-d189-451e-9f0a-5611020583a2
# 22902   c3971b3f-fe66-45a1-a81a-9426a14d62c5
# 33586   bc281b7f-8c99-40c8-96ba-458b2140953c
# ...                                      ...
# 175553  d84104b7-d380-4378-b5ad-5d9a35f904da
# 176529  ce3b0c1b-091f-4b15-843f-5199d5cb4a44
# 193963  e11c4f09-0bf7-4e46-87ec-4cb5c41d089d
# 195033  2cfa8449-d728-4589-8291-c79d35f722d1
# 195850  0760bfca-c724-46d1-bb60-c55c6d8a09f7
#
#                                  course_uuid                    course_name  \
# 6250    12bb6bfa-8b01-46a8-8cc2-e0e84785fa1e  Face-to-face regional concept
# 17671   12bb6bfa-8b01-46a8-8cc2-e0e84785fa1e  Face-to-face regional concept
# 19936   12bb6bfa-8b01-46a8-8cc2-e0e84785fa1e  Face-to-face regional concept
# 22902   12bb6bfa-8b01-46a8-8cc2-e0e84785fa1e  Face-to-face regional concept
# 33586   12bb6bfa-8b01-46a8-8cc2-e0e84785fa1e  Face-to-face regional concept
# ...                                      ...                            ...
# 175553  12bb6bfa-8b01-46a8-8cc2-e0e84785fa1e  Face-to-face regional concept
# 176529  12bb6bfa-8b01-46a8-8cc2-e0e84785fa1e  Face-to-face regional concept
# 193963  12bb6bfa-8b01-46a8-8cc2-e0e84785fa1e  Face-to-face regional concept
# 195033  12bb6bfa-8b01-46a8-8cc2-e0e84785fa1e  Face-to-face regional concept
# 195850  12bb6bfa-8b01-46a8-8cc2-e0e84785fa1e  Face-to-face regional concept
#
#            legajo                                              index
# 6250    156893QYV  9f4a4427-4807-4b56-8f32-024a45037ba4/12bb6bfa-...
# 17671   743472NZS  b8d84394-f416-4b70-b831-782dcb8998ca/12bb6bfa-...
# 19936   442882JXU  9940480d-d189-451e-9f0a-5611020583a2/12bb6bfa-...
# 22902   461434CGD  c3971b3f-fe66-45a1-a81a-9426a14d62c5/12bb6bfa-...
# 33586   493223ERG  bc281b7f-8c99-40c8-96ba-458b2140953c/12bb6bfa-...
# ...           ...                                                ...
# 175553  452142XVV  d84104b7-d380-4378-b5ad-5d9a35f904da/12bb6bfa-...
# 176529  573414YQK  ce3b0c1b-091f-4b15-843f-5199d5cb4a44/12bb6bfa-...
# 193963  389382QSU  e11c4f09-0bf7-4e46-87ec-4cb5c41d089d/12bb6bfa-...
# 195033  817962JMH  2cfa8449-d728-4589-8291-c79d35f722d1/12bb6bfa-...
# 195850  777338EQM  0760bfca-c724-46d1-bb60-c55c6d8a09f7/12bb6bfa-...
#
# [81 rows x 25 columns]
